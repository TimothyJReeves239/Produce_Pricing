# %%
import pandas as pd

# %%
data = pd.read_csv("Store_Data/ConsolidateOutput.csv")

# %%
data = data.drop(["Unnamed: 0.1", "Unnamed: 0"], axis = 1)

# %%
dataAvocado = data[ data["produce"].str.contains("Large Hass Avocado") ]

# %%
data.head()
# Out:
#                 location                             produce    prices
# 0  Bedford New Hampshire  Organic Large Hass Avocado, 1 each     $1.99
# 1  Bedford New Hampshire          Large Hass Avocado, 1 each     $1.99
# 2  Bedford New Hampshire            Organic Honeycrisp Apple  $3.99/lb
# 3  Bedford New Hampshire        Whole Trade® Organic Bananas    69¢/lb
# 4  Bedford New Hampshire                    Organic Broccoli  $2.49/lb

# %%
dataAvocado
# Out:
#                   location                             produce prices
# 0    Bedford New Hampshire  Organic Large Hass Avocado, 1 each  $1.99
# 1    Bedford New Hampshire          Large Hass Avocado, 1 each  $1.99
# 40                 Beverly  Organic Large Hass Avocado, 1 each  $1.99
# 41                 Beverly          Large Hass Avocado, 1 each  $1.99
# 60               West Cary          Large Hass Avocado, 1 each  $1.99
# 100               Westford  Organic Large Hass Avocado, 1 each  $1.99
# 101               Westford          Large Hass Avocado, 1 each  $1.99
# 120          Union Station  Organic Large Hass Avocado, 1 each  $2.49
# 121          Union Station          Large Hass Avocado, 1 each  $1.99
# 140             Shrewsbury          Large Hass Avocado, 1 each  $1.99
# 180               Cityline          Large Hass Avocado, 1 each  $1.99
# 200       Madison Broadway  Organic Large Hass Avocado, 1 each  $2.49
# ...
